# %% [markdown]
# <h1>Fáza 1 - prieskumná analýza

# %% [markdown]
# <h2>Základný opis dát spolu s ich charakteristikami
# <h3>Uloha 1:

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import scipy.stats as stats

stations = []
measurements = []


lenght_cf = 0
lenght_df = 0
filename = "data/" + "0"+ str(25) + '/'
        
cf = pd.read_csv(filename+ "measurements.csv",sep ='\t')
measurements = cf
df = pd.read_csv(filename+ "stations.csv",sep ='\t')
stations=df
        
        
   
    #print(cf.shape)
    #print(df.shape)
    #lenght_cf = lenght_cf + len(cf)
    #lenght_df = lenght_df + len(df)
    
measurements.shape
# Out:
# (12101, 18)

# %%
measurements.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12101 entries, 0 to 12100
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   PM10       12052 non-null  float64
#  1   NH3        12050 non-null  float64
#  2   warning    12053 non-null  float64
#  3   H2CO       12052 non-null  float64
#  4   SO2        12052 non-null  float64
#  5   TEMP       12053 non-null  float64
#  6   C2H3NO5    12053 non-null  float64
#  7   Pb         12052 non-null  float64
#  8   NOx        12051 non-null  float64
#  9   PM2.5      12052 non-null  float64
#  10  latitude   12101 non-null  float64
#  11  PRES       12101 non-null  float64
#  12  longitude  12101 non-null  float64
#  13  CH4        12053 non-null  float64
#  14  PAHs       12053 non-null  float64
#  15  CFCs       12052 non-null  float64
#  16  CO         12053 non-null  float64
#  17  O3         12051 non-null  float64
# dtypes: float64(18)
# memory usage: 1.7 MB

# %%
stations.shape
# Out:
# (1078, 6)

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1078 entries, 0 to 1077
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   location   1078 non-null   object
#  1   revision   1078 non-null   object
#  2   longitude  1078 non-null   float64
#  3   QoS        1078 non-null   object
#  4   code       1078 non-null   object
#  5   latitude   1078 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 50.7+ KB

# %% [markdown]
# <h3>Deskriptívna štatistika:

# %%
measurements['CO'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12101 entries, 0 to 12100
# Series name: CO
# Non-Null Count  Dtype
# --------------  -----
# 12053 non-null  float64
# dtypes: float64(1)
# memory usage: 94.7 KB

# %%
measurements['CO'].describe()
# Out:
# count    12053.000000
# mean         7.980943
# std          1.852905
# min          0.804270
# 25%          6.678780
# 50%          8.135410
# 75%          9.383080
# max         13.126980
# Name: CO, dtype: float64

# %%
sns.distplot(measurements['CO'], kde=True)
# Out:
# C:\Users\ntb\AppData\Local\Temp\ipykernel_12396\3283759024.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(measurements['CO'], kde=True)
# <AxesSubplot: xlabel='CO', ylabel='Density'>

# %%
x = measurements[['CO', 'warning']]
x = x[x.warning == 1]
x['CO'].hist(rwidth=0.85)
# Out:
# <AxesSubplot: >

# %%
x = measurements[['CO', 'warning']]
x = x[x.warning == 0]
x['CO'].hist(rwidth=0.85)
# Out:
# <AxesSubplot: >

# %%
measurements["PM2.5"].describe()
# Out:
# count    12052.000000
# mean         7.970386
# std          1.004556
# min          4.019010
# 25%          7.297195
# 50%          7.969780
# 75%          8.640042
# max         12.141360
# Name: PM2.5, dtype: float64

# %%
measurements["PM2.5"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 12101 entries, 0 to 12100
# Series name: PM2.5
# Non-Null Count  Dtype
# --------------  -----
# 12052 non-null  float64
# dtypes: float64(1)
# memory usage: 94.7 KB

# %%
x = measurements[['PM2.5', 'warning']]
x = x[x.warning == 0]
sns.distplot(x['PM2.5'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [21], line 3
#       1 x = measurements[['PM2.5', 'warning']]
#       2 x = x[x.warning == 0]
# ----> 3 sns.distplot(x['PM2.5'],rwidth=0.85)
#
# TypeError: distplot() got an unexpected keyword argument 'rwidth'

# %%
x = measurements[['PM2.5', 'warning']]
x = x[x.warning == 1]
sns.distplot(x['PM2.5'])
# Out:
# C:\Users\ntb\AppData\Local\Temp\ipykernel_12396\4195415478.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x['PM2.5'])
# <AxesSubplot: xlabel='PM2.5', ylabel='Density'>

# %%
measurements[measurements.warning == 0].describe()
# Out:
#               PM10          NH3  warning         H2CO          SO2  \
# count  4878.000000  4871.000000   4893.0  4871.000000  4876.000000
# mean      9.163642     6.695183      0.0    50.340709     7.973707
# std       1.810498     1.365687      0.0    13.664003     1.785040
# min       1.922940     0.000000      0.0     0.000000     2.718990
# 25%       7.996120     5.831835      0.0    41.563835     6.598907
# 50%       9.166215     6.672690      0.0    50.453340     7.813435
# 75%      10.309567     7.579345      0.0    59.325265     9.285165
# max      16.078750    12.253040      0.0    97.784900    14.354340
#
#               TEMP      C2H3NO5           Pb          NOx        PM2.5  \
# count  4867.000000  4870.000000  4877.000000  4877.000000  4861.000000
# mean     15.015414     0.581483    46.763519     7.943171     7.977579
# std       9.986942     2.664720    13.155566     1.990399     0.999091
# min     -19.123330     0.011490     2.984400     0.978510     4.344390
# ...

# %% [markdown]
# <h3> Párová analýza

# %%
sns.regplot(data = measurements, x ="PM2.5", y = "CO")
# Out:
# <AxesSubplot: xlabel='PM2.5', ylabel='CO'>
